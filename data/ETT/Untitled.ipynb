# %%
import torch
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv('testdata.csv')

# %%
cols = list(df_raw.columns); cols.remove(target); cols.remove('date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15536\1013176522.py in <module>
# ----> 1 cols = list(df_raw.columns); cols.remove(target); cols.remove('date')
#
# NameError: name 'target' is not defined
