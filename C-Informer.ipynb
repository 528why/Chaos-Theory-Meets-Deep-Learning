# %% [markdown]
# # Informer Demo

# %% [markdown]
# ## Download code and dataset

# %%
# !git clone https://github.com/zhouhaoyi/Informer2020.git
# !git clone https://github.com/zhouhaoyi/ETDataset.git
# !ls

# %%
# import sys
# if not 'Informer2020' in sys.path:
#     sys.path += ['Informer2020']

# %%
# !pip install -r ./Informer2020/requirements.txt

# %% [markdown]
# ## Experiments: Train and Test

# %%
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch
import time
from torchvision import models
from gpu_mem_track import MemTracker

# %%
args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'ETTh2' # data
args.root_path = './data/ETT/' # root path of data file
args.data_path = 'ETTh2.csv' # data file
args.features = 'MS' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'OT' # target feature in S or MS task
args.freq = 'd' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 48 # input sequence length of Informer encoder
args.label_len = 48 # start token length of Informer decoder
args.pred_len = 24 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 7 # encoder input size
args.dec_in = 7 # decoder input size
args.c_out = 10 # output size
args.factor = 3 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder
args.mix = True
args.padding = 0
args.freq = 'h'


args.batch_size = 32 
args.learning_rate = 0.001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr =1
args.train_epochs = 100
args.patience = 100
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

#args.inverse = True

# %%
args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
# Set augments by using data name
data_parser = {
    'ETTh1':{'data':'ETTh1.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTh2':{'data':'ETTh2.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTm1':{'data':'ETTm1.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
    'ETTm2':{'data':'ETTm2.csv','T':'OT','M':[7,7,7],'S':[1,1,1],'MS':[7,7,1]},
}
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# %%
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# %%
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTh2', 'root_path': './data/ETT/', 'data_path': 'ETTh2.csv', 'features': 'MS', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 48, 'label_len': 48, 'pred_len': 24, 'enc_in': 7, 'dec_in': 7, 'c_out': 1, 'factor': 3, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 100, 'patience': 100, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
Exp = Exp_Informer

# %%
gpu_tracker = MemTracker()   
gpu_tracker.track()

t0 = time.time()
print('程序开始时间:', time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
for ii in range(args.itr):
    
    # setting record of experiments
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features, 
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # set experiments
    exp = Exp(args)
    
    # train
    print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
    t0_train = time.time()
    exp.train(setting)
    t1_train = time.time()
    print("训练用时：%.6fs" % (t1_train - t0_train))
    
    # test
    print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
    t0_test = time.time()
    exp.test(setting)
    t1_test = time.time()
    print("测试用时：%.6fs" % (t1_test - t0_test))
    
    torch.cuda.empty_cache()

t1 = time.time()
print('程序结束时间:', time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
print("用时：%.6fs" % (t1 - t0))

gpu_tracker.track()
# Out:
# 程序开始时间: 2024-05-18 02:30:41
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh2_ftMS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8569
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.3924817
# 	speed: 0.0694s/iter; left time: 1845.6483s
# 	iters: 200, epoch: 1 | loss: 0.2049196
# 	speed: 0.0427s/iter; left time: 1132.2586s
# Epoch: 1 cost time: 14.09951400756836
# Epoch: 1, Steps: 267 | Train Loss: 0.3785659 Vali Loss: 0.3735894 Test Loss: 0.4081044
# Validation loss decreased (inf --> 0.373589).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 0.1425485
# 	speed: 0.1123s/iter; left time: 2956.0846s
# 	iters: 200, epoch: 2 | loss: 0.1777098
# 	speed: 0.0427s/iter; left time: 1120.3128s
# Epoch: 2 cost time: 11.398709058761597
# Epoch: 2, Steps: 267 | Train Loss: 0.2089522 Vali Loss: 0.2209401 Test Loss: 0.3175695
# Validation loss decreased (0.373589 --> 0.220940).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 0.1897360
# 	speed: 0.1140s/iter; left time: 2970.9458s
# 	iters: 200, epoch: 3 | loss: 0.1910732
# 	speed: 0.0422s/iter; left time: 1095.7033s
# Epoch: 3 cost time: 11.29723072052002
# Epoch: 3, Steps: 267 | Train Loss: 0.1889524 Vali Loss: 0.1886870 Test Loss: 0.3904995
# Validation loss decreased (0.220940 --> 0.188687).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 0.1649463
# 	speed: 0.1128s/iter; left time: 2910.1493s
# 	iters: 200, epoch: 4 | loss: 0.2049946
# 	speed: 0.0420s/iter; left time: 1079.0984s
# Epoch: 4 cost time: 11.229866027832031
# Epoch: 4, Steps: 267 | Train Loss: 0.1783197 Vali Loss: 0.2131521 Test Loss: 0.3826915
# EarlyStopping counter: 1 out of 100
# Updating learning rate to 0.000125
# 	iters: 100, epoch: 5 | loss: 0.1417922
# 	speed: 0.0959s/iter; left time: 2448.8293s
# 	iters: 200, epoch: 5 | loss: 0.1710610
# 	speed: 0.0424s/iter; left time: 1079.4650s
# Epoch: 5 cost time: 11.29745101928711
# Epoch: 5, Steps: 267 | Train Loss: 0.1736141 Vali Loss: 0.2025522 Test Loss: 0.4562511
# EarlyStopping counter: 2 out of 100
# Updating learning rate to 6.25e-05
# 	iters: 100, epoch: 6 | loss: 0.1482087
# 	speed: 0.0974s/iter; left time: 2460.6616s
# 	iters: 200, epoch: 6 | loss: 0.1620498
# 	speed: 0.0428s/iter; left time: 1077.7329s
# Epoch: 6 cost time: 11.403152465820312
# Epoch: 6, Steps: 267 | Train Loss: 0.1700328 Vali Loss: 0.1947455 Test Loss: 0.2857197
# EarlyStopping counter: 3 out of 100
# Updating learning rate to 3.125e-05
# 	iters: 100, epoch: 7 | loss: 0.1955764
# 	speed: 0.0959s/iter; left time: 2397.8100s
# 	iters: 200, epoch: 7 | loss: 0.1884998
# 	speed: 0.0418s/iter; left time: 1041.4344s
# Epoch: 7 cost time: 11.14862060546875
# Epoch: 7, Steps: 267 | Train Loss: 0.1675790 Vali Loss: 0.1927529 Test Loss: 0.3226820
# EarlyStopping counter: 4 out of 100
# Updating learning rate to 1.5625e-05
# 	iters: 100, epoch: 8 | loss: 0.1496214
# 	speed: 0.0955s/iter; left time: 2362.0341s
# 	iters: 200, epoch: 8 | loss: 0.1382556
# 	speed: 0.0423s/iter; left time: 1041.9330s
# 	speed: 0.0419s/iter; left time: 953.8614s
# Epoch: 15 cost time: 11.274542093276978
# Epoch: 15, Steps: 267 | Train Loss: 0.1659583 Vali Loss: 0.1938712 Test Loss: 0.3214943
# EarlyStopping counter: 7 out of 100
# Updating learning rate to 6.103515625e-08
# 	iters: 100, epoch: 16 | loss: 0.1491312
# 	speed: 0.0952s/iter; left time: 2150.6559s
# 	iters: 200, epoch: 16 | loss: 0.1811951
# 	speed: 0.0427s/iter; left time: 959.9746s
# Epoch: 16 cost time: 11.35486102104187
# Epoch: 16, Steps: 267 | Train Loss: 0.1656014 Vali Loss: 0.1887544 Test Loss: 0.3217523
# EarlyStopping counter: 8 out of 100
# Updating learning rate to 3.0517578125e-08
# 	iters: 100, epoch: 17 | loss: 0.1764329
# 	speed: 0.0991s/iter; left time: 2213.8902s
# 	iters: 200, epoch: 17 | loss: 0.1739774
# 	speed: 0.0436s/iter; left time: 968.2411s
# Epoch: 17 cost time: 11.543941259384155
# Epoch: 17, Steps: 267 | Train Loss: 0.1653624 Vali Loss: 0.1897426 Test Loss: 0.3157392
# EarlyStopping counter: 9 out of 100
# Updating learning rate to 1.52587890625e-08
# 	iters: 100, epoch: 18 | loss: 0.1978760
# 	speed: 0.0969s/iter; left time: 2138.3082s
# 	iters: 200, epoch: 18 | loss: 0.1794301
# 	speed: 0.0423s/iter; left time: 929.1335s
# Epoch: 18 cost time: 11.258387327194214
# Epoch: 18, Steps: 267 | Train Loss: 0.1657375 Vali Loss: 0.1894277 Test Loss: 0.3133939
# EarlyStopping counter: 10 out of 100
# Updating learning rate to 7.62939453125e-09
# 	iters: 100, epoch: 19 | loss: 0.1713182
# 	speed: 0.0967s/iter; left time: 2107.9861s
# 	iters: 200, epoch: 19 | loss: 0.1659105
# 	speed: 0.0425s/iter; left time: 922.4006s
# Epoch: 19 cost time: 11.283414840698242
# Epoch: 19, Steps: 267 | Train Loss: 0.1651911 Vali Loss: 0.1901983 Test Loss: 0.3246017
# EarlyStopping counter: 11 out of 100
# Updating learning rate to 3.814697265625e-09
# 	iters: 100, epoch: 20 | loss: 0.1562071
# 	speed: 0.0968s/iter; left time: 2083.0074s
# 	iters: 200, epoch: 20 | loss: 0.1596312
# 	speed: 0.0421s/iter; left time: 902.3189s
# Epoch: 20 cost time: 11.224607706069946
# Epoch: 20, Steps: 267 | Train Loss: 0.1666210 Vali Loss: 0.1879387 Test Loss: 0.3071967
# EarlyStopping counter: 12 out of 100
# Updating learning rate to 1.9073486328125e-09
# 	iters: 100, epoch: 21 | loss: 0.1693127
# 	speed: 0.0957s/iter; left time: 2034.5084s
# 	iters: 200, epoch: 21 | loss: 0.1765001
# 	speed: 0.0429s/iter; left time: 908.1818s
# Epoch: 21 cost time: 11.353387117385864
# Epoch: 21, Steps: 267 | Train Loss: 0.1658977 Vali Loss: 0.1884187 Test Loss: 0.3108135
# EarlyStopping counter: 13 out of 100
# Updating learning rate to 9.5367431640625e-10
# 	iters: 100, epoch: 22 | loss: 0.1578462
# 	speed: 0.0977s/iter; left time: 2051.8116s
# 	iters: 200, epoch: 22 | loss: 0.1223565
# 	speed: 0.0428s/iter; left time: 895.0333s
# Epoch: 22 cost time: 11.420437335968018
# Epoch: 22, Steps: 267 | Train Loss: 0.1657647 Vali Loss: 0.1895637 Test Loss: 0.3105406
# EarlyStopping counter: 14 out of 100
# Updating learning rate to 4.76837158203125e-10
# 	iters: 100, epoch: 23 | loss: 0.1579833
# 	speed: 0.0959s/iter; left time: 1986.8879s
# 	iters: 200, epoch: 23 | loss: 0.1665769
# 	speed: 0.0427s/iter; left time: 881.7320s
# Epoch: 23 cost time: 11.353868007659912
# Epoch: 23, Steps: 267 | Train Loss: 0.1655182 Vali Loss: 0.1896504 Test Loss: 0.3272372
# EarlyStopping counter: 15 out of 100
# Updating learning rate to 2.384185791015625e-10
# 	iters: 100, epoch: 24 | loss: 0.1739606
# 	speed: 0.0969s/iter; left time: 1981.5799s
# 	iters: 200, epoch: 24 | loss: 0.1323390
# 	speed: 0.0422s/iter; left time: 858.4447s
# Epoch: 24 cost time: 11.262869358062744
# Epoch: 24, Steps: 267 | Train Loss: 0.1661505 Vali Loss: 0.1920368 Test Loss: 0.3184932
# EarlyStopping counter: 16 out of 100
# Updating learning rate to 1.1920928955078125e-10
# 	iters: 100, epoch: 25 | loss: 0.1577425
# 	speed: 0.0962s/iter; left time: 1941.9714s
# 	iters: 200, epoch: 25 | loss: 0.1898050
# 	speed: 0.0423s/iter; left time: 850.5694s
# Epoch: 25 cost time: 11.286139011383057
# Epoch: 25, Steps: 267 | Train Loss: 0.1661965 Vali Loss: 0.1935661 Test Loss: 0.3306684
# EarlyStopping counter: 17 out of 100
# Updating learning rate to 5.960464477539063e-11
# 	iters: 100, epoch: 26 | loss: 0.1929573
# 	speed: 0.0959s/iter; left time: 1911.5117s
# 	iters: 200, epoch: 26 | loss: 0.1549276
# 	speed: 0.0423s/iter; left time: 838.0332s
# Epoch: 26 cost time: 11.2412748336792
# Epoch: 26, Steps: 267 | Train Loss: 0.1657050 Vali Loss: 0.1913553 Test Loss: 0.3084571
# EarlyStopping counter: 18 out of 100
# Updating learning rate to 2.980232238769531e-11
# 	iters: 100, epoch: 27 | loss: 0.1535330
# 	speed: 0.0961s/iter; left time: 1888.9146s
# 	iters: 200, epoch: 27 | loss: 0.1964256
# 	speed: 0.0424s/iter; left time: 829.1870s
# Epoch: 27 cost time: 11.264254331588745
# Epoch: 27, Steps: 267 | Train Loss: 0.1656461 Vali Loss: 0.1896593 Test Loss: 0.3224132
# EarlyStopping counter: 19 out of 100
# Updating learning rate to 1.4901161193847657e-11
# 	iters: 100, epoch: 28 | loss: 0.1650498
# 	speed: 0.0959s/iter; left time: 1860.1015s
# 	iters: 200, epoch: 28 | loss: 0.1655665
# 	speed: 0.0421s/iter; left time: 812.0097s
# Epoch: 28 cost time: 11.233119249343872
# Epoch: 28, Steps: 267 | Train Loss: 0.1656115 Vali Loss: 0.1889332 Test Loss: 0.3167389
# EarlyStopping counter: 20 out of 100
# Updating learning rate to 7.450580596923828e-12
# 	iters: 100, epoch: 29 | loss: 0.1615809
# 	speed: 0.0422s/iter; left time: 420.1742s
# Epoch: 63 cost time: 11.24465799331665
# Epoch: 63, Steps: 267 | Train Loss: 0.1656747 Vali Loss: 0.1924183 Test Loss: 0.3240652
# EarlyStopping counter: 4 out of 100
# Updating learning rate to 2.168404344971009e-22
# 	iters: 100, epoch: 64 | loss: 0.1689632
# 	speed: 0.0965s/iter; left time: 943.4804s
# 	iters: 200, epoch: 64 | loss: 0.2033020
# 	speed: 0.0419s/iter; left time: 405.9206s
# Epoch: 64 cost time: 11.169549942016602
# Epoch: 64, Steps: 267 | Train Loss: 0.1661397 Vali Loss: 0.1911191 Test Loss: 0.3145525
# EarlyStopping counter: 5 out of 100
# Updating learning rate to 1.0842021724855045e-22
# 	iters: 100, epoch: 65 | loss: 0.2162661
# 	speed: 0.0955s/iter; left time: 908.3906s
# 	iters: 200, epoch: 65 | loss: 0.1694162
# 	speed: 0.0424s/iter; left time: 398.9802s
# Epoch: 65 cost time: 11.257269144058228
# Epoch: 65, Steps: 267 | Train Loss: 0.1657496 Vali Loss: 0.1872502 Test Loss: 0.3116247
# EarlyStopping counter: 6 out of 100
# Updating learning rate to 5.421010862427522e-23
# 	iters: 100, epoch: 66 | loss: 0.1844509
# 	speed: 0.0967s/iter; left time: 894.0414s
# 	iters: 200, epoch: 66 | loss: 0.1163144
# 	speed: 0.0426s/iter; left time: 389.5315s
# Epoch: 66 cost time: 11.289684772491455
# Epoch: 66, Steps: 267 | Train Loss: 0.1654077 Vali Loss: 0.1948553 Test Loss: 0.3248100
# EarlyStopping counter: 7 out of 100
# Updating learning rate to 2.710505431213761e-23
# 	iters: 100, epoch: 67 | loss: 0.2229923
# 	speed: 0.0982s/iter; left time: 882.1804s
# 	iters: 200, epoch: 67 | loss: 0.1368336
# 	speed: 0.0423s/iter; left time: 375.6412s
# Epoch: 67 cost time: 11.262534379959106
# Epoch: 67, Steps: 267 | Train Loss: 0.1654382 Vali Loss: 0.1893513 Test Loss: 0.3175473
# EarlyStopping counter: 8 out of 100
# Updating learning rate to 1.3552527156068806e-23
# 	iters: 100, epoch: 68 | loss: 0.1759938
# 	speed: 0.0970s/iter; left time: 845.4974s
# 	iters: 200, epoch: 68 | loss: 0.1705064
# 	speed: 0.0423s/iter; left time: 364.0192s
# Epoch: 68 cost time: 11.28676986694336
# Epoch: 68, Steps: 267 | Train Loss: 0.1659442 Vali Loss: 0.1902889 Test Loss: 0.3245896
# EarlyStopping counter: 9 out of 100
# Updating learning rate to 6.776263578034403e-24
# 	iters: 100, epoch: 69 | loss: 0.1962523
# 	speed: 0.0969s/iter; left time: 818.5542s
# 	iters: 200, epoch: 69 | loss: 0.1651863
# 	speed: 0.0422s/iter; left time: 352.5501s
# Epoch: 69 cost time: 11.245035409927368
# Epoch: 69, Steps: 267 | Train Loss: 0.1660799 Vali Loss: 0.1913983 Test Loss: 0.3143567
# EarlyStopping counter: 10 out of 100
# Updating learning rate to 3.3881317890172014e-24
# 	iters: 100, epoch: 70 | loss: 0.1562369
# 	speed: 0.0968s/iter; left time: 791.9851s
# EarlyStopping counter: 38 out of 100
# Updating learning rate to 1.262177448353619e-32
# 	iters: 100, epoch: 98 | loss: 0.1577868
# 	speed: 0.0967s/iter; left time: 67.8832s
# 	iters: 200, epoch: 98 | loss: 0.1896101
# 	speed: 0.0429s/iter; left time: 25.8361s
# Epoch: 98 cost time: 11.40256643295288
# Epoch: 98, Steps: 267 | Train Loss: 0.1661136 Vali Loss: 0.1933032 Test Loss: 0.3302168
# EarlyStopping counter: 39 out of 100
# Updating learning rate to 6.310887241768095e-33
# 	iters: 100, epoch: 99 | loss: 0.1612707
# 	speed: 0.0970s/iter; left time: 42.2005s
# 	iters: 200, epoch: 99 | loss: 0.1281934
# 	speed: 0.0427s/iter; left time: 14.3175s
# Epoch: 99 cost time: 11.396150827407837
# Epoch: 99, Steps: 267 | Train Loss: 0.1653310 Vali Loss: 0.1914250 Test Loss: 0.3213750
# EarlyStopping counter: 40 out of 100
# Updating learning rate to 3.155443620884047e-33
# 	iters: 100, epoch: 100 | loss: 0.1525361
# 	speed: 0.0967s/iter; left time: 16.2491s
# 	iters: 200, epoch: 100 | loss: 0.1574220
# 	speed: 0.0427s/iter; left time: 2.9055s
# Epoch: 100 cost time: 11.368143081665039
# Epoch: 100, Steps: 267 | Train Loss: 0.1655960 Vali Loss: 0.1917695 Test Loss: 0.3232764
# EarlyStopping counter: 41 out of 100
# Updating learning rate to 1.5777218104420236e-33
# 训练用时：1405.357423s
# >>>>>>>testing : informer_ETTh2_ftMS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.3030996024608612, mae:0.46954968571662903, rmse:0.550544798374176, mape:0.8836655616760254, mspe:22.49112892150879
# 测试用时：1.332423s
# 程序结束时间: 2024-05-18 02:54:29
# 用时：1427.920616s

# %% [markdown]
# ## Prediction

# %%
import os

# set saved model path

setting = 'informer_custom_ftS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_exp_4'
# path = os.path.join(args.checkpoints,setting,'checkpoint.pth')

# %%
# If you already have a trained model, you can set the arguments and model path, then initialize a Experiment and use it to predict
# Prediction is a sequence which is adjacent to the last date of the data, and does not exist in the data
# If you want to get more information about prediction, you can refer to code `exp/exp_informer.py function predict()` and `data/data_loader.py class Dataset_Pred`

exp = Exp(args)

exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 7
#       1 # If you already have a trained model, you can set the arguments and model path, then initialize a Experiment and use it to predict
#       2 # Prediction is a sequence which is adjacent to the last date of the data, and does not exist in the data
#       3 # If you want to get more information about prediction, you can refer to code `exp/exp_informer.py function predict()` and `data/data_loader.py class Dataset_Pred`
#       5 exp = Exp(args)
# ----> 7 exp.predict(setting, True)
#
# File /mnt/why/py_chaotic/Chaotic Deep Learning Model for time series prediction/informer_chaos/exp/exp_informer.py:260, in Exp_Informer.predict(self, setting, load)
#     258     path = os.path.join(self.args.checkpoints, setting)
#     259     best_model_path = path+'/'+'checkpoint.pth'
# --> 260     self.model.load_state_dict(torch.load(best_model_path))
#     262 self.model.eval()
#     264 preds = []
#
# File ~/miniconda3/envs/myconda/lib/python3.10/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Informer:
# 	size mismatch for enc_embedding.value_embedding.tokenConv.weight: copying a param with shape torch.Size([512, 1, 3]) from checkpoint, the shape in current model is torch.Size([512, 7, 3]).
# 	size mismatch for dec_embedding.value_embedding.tokenConv.weight: copying a param with shape torch.Size([512, 1, 3]) from checkpoint, the shape in current model is torch.Size([512, 7, 3]).
# 	size mismatch for projection.weight: copying a param with shape torch.Size([10, 512]) from checkpoint, the shape in current model is torch.Size([1, 512]).
# 	size mismatch for projection.bias: copying a param with shape torch.Size([10]) from checkpoint, the shape in current model is torch.Size([1]).

# %%
# the prediction will be saved in ./results/{setting}/real_prediction.npy
import numpy as np

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

# %% [markdown]
# ### More details about Prediction - prediction function

# %%
# here is the detailed code of function predict

def predict(exp, setting, load=False):
    pred_data, pred_loader = exp._get_data(flag='pred')
        
    if load:
        path = os.path.join(exp.args.checkpoints, setting)
        best_model_path = path+'/'+'checkpoint.pth'
        exp.model.load_state_dict(torch.load(best_model_path))

    exp.model.eval()
        
    preds = []
        
    for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
        batch_x = batch_x.float().to(exp.device)
        batch_y = batch_y.float()
        batch_x_mark = batch_x_mark.float().to(exp.device)
        batch_y_mark = batch_y_mark.float().to(exp.device)

        # decoder input
        if exp.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        elif exp.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        else:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:exp.args.label_len,:], dec_inp], dim=1).float().to(exp.device)
        # encoder - decoder
        if exp.args.use_amp:
            with torch.cuda.amp.autocast():
                if exp.args.output_attention:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if exp.args.output_attention:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        f_dim = -1 if exp.args.features=='MS' else 0
        batch_y = batch_y[:,-exp.args.pred_len:,f_dim:].to(exp.device)
        
        pred = outputs.detach().cpu().numpy()#.squeeze()
        
        preds.append(pred)

    preds = np.array(preds)
    preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
    
    # result save
    folder_path = './results/' + setting +'/'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    np.save(folder_path+'real_prediction.npy', preds)
    
    return preds

# %%
# you can also use this prediction function to get result
prediction = predict(exp, setting, True)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

# %% [markdown]
# ### More details about Prediction - prediction dataset
#
# You can give a `root_path` and `data_path` of the data you want to forecast, and set `seq_len`, `label_len`, `pred_len` and other arguments as other Dataset. The difference is that you can set a more detailed freq such as `15min` or `3h` to generate the timestamp of prediction series.
#
# `Dataset_Pred` only has one sample (including `encoder_input: [1, seq_len, dim]`, `decoder_token: [1, label_len, dim]`, `encoder_input_timestamp: [1, seq_len, date_dim]`, `decoder_input_timstamp: [1, label_len+pred_len, date_dim]`). It will intercept the last sequence of the given data (seq_len data) to forecast the unseen future sequence (pred_len data).

# %%
from data.data_loader import Dataset_Pred
from torch.utils.data import DataLoader

# %%
Data = Dataset_Pred
timeenc = 0 if args.embed!='timeF' else 1
flag = 'pred'; shuffle_flag = False; drop_last = False; batch_size = 1

freq = args.detail_freq

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    target=args.target,
    timeenc=timeenc,
    freq=freq
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
len(data_set), len(data_loader)

# %% [markdown]
# ## Visualization

# %%
# When we finished exp.train(setting) and exp.test(setting), we will get a trained model and the results of test experiment
# The results of test experiment will be saved in ./results/{setting}/pred.npy (prediction of test dataset) and ./results/{setting}/true.npy (groundtruth of test dataset)

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

# [samples, pred_len, dimensions]
preds.shape, trues.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# draw OT prediction
plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# draw HUFL prediction
plt.figure()
plt.plot(trues[0,:,0], label='GroundTruth')
plt.plot(preds[0,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
from data.data_loader import Dataset_ETT_hour
from torch.utils.data import DataLoader

Data = Dataset_ETT_hour
timeenc = 0 if args.embed!='timeF' else 1
flag = 'test'; shuffle_flag = False; drop_last = True; batch_size = 1

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    timeenc=timeenc,
    freq=args.freq
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
import os

args.output_attention = True

exp = Exp(args)

model = exp.model

setting = 'informer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'
path = os.path.join(args.checkpoints,setting,'checkpoint.pth')
model.load_state_dict(torch.load(path))

# %%
# attention visualization
idx = 0
for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(data_loader):
    if i!=idx:
        continue
    batch_x = batch_x.float().to(exp.device)
    batch_y = batch_y.float()

    batch_x_mark = batch_x_mark.float().to(exp.device)
    batch_y_mark = batch_y_mark.float().to(exp.device)
    
    dec_inp = torch.zeros_like(batch_y[:,-args.pred_len:,:]).float()
    dec_inp = torch.cat([batch_y[:,:args.label_len,:], dec_inp], dim=1).float().to(exp.device)
    
    outputs,attn = model(batch_x, batch_x_mark, dec_inp, batch_y_mark)

# %%
attn[0].shape, attn[1].shape #, attn[2].shape

# %%
layer = 0
distil = 'Distil' if args.distil else 'NoDistil'
for h in range(0,8):
    plt.figure(figsize=[10,8])
    plt.title('Informer, {}, attn:{} layer:{} head:{}'.format(distil, args.attn, layer, h))
    A = attn[layer][0,h].detach().cpu().numpy()
    ax = sns.heatmap(A, vmin=0, vmax=A.max()+0.01)
    plt.show()

# %%
layer = 1
distil = 'Distil' if args.distil else 'NoDistil'
for h in range(0,8):
    plt.figure(figsize=[10,8])
    plt.title('Informer, {}, attn:{} layer:{} head:{}'.format(distil, args.attn, layer, h))
    A = attn[layer][0,h].detach().cpu().numpy()
    ax = sns.heatmap(A, vmin=0, vmax=A.max()+0.01)
    plt.show()

# %% [markdown]
# ## Custom Data
#
# Custom data (xxx.csv) has to include at least 2 features: `date`(format: `YYYY-MM-DD hh:mm:ss`) and `target feature`.

# %%
from data.data_loader import Dataset_Custom
from torch.utils.data import DataLoader
import pandas as pd
import os

# %%
# custom data: xxx.csv
# data features: ['date', ...(other features), target feature]

# we take ETTh2 as an example
args.root_path = './ETDataset/ETT-small/'
args.data_path = 'ETTh2.csv'

df = pd.read_csv(os.path.join(args.root_path, args.data_path))

# %%
df.head()

# %%
'''
We set 'HULL' as target instead of 'OT'

The following frequencies are supported:
        Y   - yearly
            alias: A
        M   - monthly
        W   - weekly
        D   - daily
        B   - business days
        H   - hourly
        T   - minutely
            alias: min
        S   - secondly
'''

args.target = 'HULL'
args.freq = 'h'

Data = Dataset_Custom
timeenc = 0 if args.embed!='timeF' else 1
flag = 'test'; shuffle_flag = False; drop_last = True; batch_size = 1

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    timeenc=timeenc,
    target=args.target, # HULL here
    freq=args.freq # 'h': hourly, 't':minutely
)
data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
batch_x,batch_y,batch_x_mark,batch_y_mark = data_set[0]
